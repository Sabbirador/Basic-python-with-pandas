# %%
import pandas as pd

# %%
df=pd.read_clipboard()
df
# Out:
#                       State_name              District_name  Population  \
# 1              JAMMU AND KASHMIR                    Kupwara      870354
# 2              JAMMU AND KASHMIR                     Badgam      753745
# 3              JAMMU AND KASHMIR                Leh(Ladakh)      133487
# 4              JAMMU AND KASHMIR                     Kargil      140802
# 5              JAMMU AND KASHMIR                      Punch      476835
# ..                           ...                        ...         ...
# 636                  PONDICHERRY                       Mahe       41816
# 637                  PONDICHERRY                   Karaikal      200222
# 638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars       36842
# 639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman      105597
# 640  ANDAMAN AND NICOBAR ISLANDS              South Andaman      238142
#
#        Male  Female  Literate  Workers  Male_Workers  Female_Workers  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                       State_name              District_name  Population  \
# 1              JAMMU AND KASHMIR                    Kupwara      870354
# 2              JAMMU AND KASHMIR                     Badgam      753745
# 3              JAMMU AND KASHMIR                Leh(Ladakh)      133487
# 4              JAMMU AND KASHMIR                     Kargil      140802
# 5              JAMMU AND KASHMIR                      Punch      476835
# ..                           ...                        ...         ...
# 636                  PONDICHERRY                       Mahe       41816
# 637                  PONDICHERRY                   Karaikal      200222
# 638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars       36842
# 639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman      105597
# 640  ANDAMAN AND NICOBAR ISLANDS              South Andaman      238142
#
#        Male  Female  Literate  Workers  Male_Workers  Female_Workers  \
# ...

# %%
df.head()
# Out:
#           State_name District_name  Population    Male  Female  Literate  \
# 1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654
# 2  JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649
# 3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516     93770
# 4  JAMMU AND KASHMIR        Kargil      140802   77785   63017     86236
# 5  JAMMU AND KASHMIR         Punch      476835  251899  224936    261724
#
#    Workers  Male_Workers  Female_Workers  Cultivator_Workers  ...  Christians  \
# 1   229064        190899           38165               34680  ...        1700
# 2   214866        162578           52288               55299  ...        1489
# 3    75079         53265           21814               20869  ...         658
# 4    51873         39839           12034                8266  ...         604
# 5   161393        117677           43716               54264  ...         958
#
# ...

# %%
df.head(15)
# Out:
#            State_name District_name  Population    Male  Female  Literate  \
# 1   JAMMU AND KASHMIR       Kupwara      870354  474190  396164    439654
# 2   JAMMU AND KASHMIR        Badgam      753745  398041  355704    335649
# 3   JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516     93770
# 4   JAMMU AND KASHMIR        Kargil      140802   77785   63017     86236
# 5   JAMMU AND KASHMIR         Punch      476835  251899  224936    261724
# 6   JAMMU AND KASHMIR       Rajouri      642415  345351  297064    364109
# 7   JAMMU AND KASHMIR        Kathua      616435  326109  290326    389204
# 8   JAMMU AND KASHMIR      Baramula     1008039  534733  473306    545149
# 9   JAMMU AND KASHMIR     Bandipore      392232  207680  184552    185979
# 10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705    748584
# 11  JAMMU AND KASHMIR     Ganderbal      297446  158720  138726    143276
# 12  JAMMU AND KASHMIR       Pulwama      560440  293064  267376    293958
# ...

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Population', 'Male', 'Female',
#        'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
df=df.drop(columns=['State_name'])
df
# Out:
#                  District_name  Population  Literate  Workers  Male_Workers  \
# 1                      Kupwara      870354    439654   229064        190899
# 2                       Badgam      753745    335649   214866        162578
# 3                  Leh(Ladakh)      133487     93770    75079         53265
# 4                       Kargil      140802     86236    51873         39839
# 5                        Punch      476835    261724   161393        117677
# ..                         ...         ...       ...      ...           ...
# 636                       Mahe       41816     36470    11802          9093
# 637                   Karaikal      200222    154916    68301         53139
# 638                   Nicobars       36842     25332    17125         12714
# 639  North  AND Middle Andaman      105597     78683    38579         30612
# 640              South Andaman      238142    190266    96831         77563
#
# ...

# %%
len(df)
# Out:
# 640

# %%
df.query("Sikhs > Jains")         #confused
# Out:
#                  District_name  Population  Literate  Workers  Male_Workers  \
# 1                      Kupwara      870354    439654   229064        190899
# 2                       Badgam      753745    335649   214866        162578
# 3                  Leh(Ladakh)      133487     93770    75079         53265
# 4                       Kargil      140802     86236    51873         39839
# 5                        Punch      476835    261724   161393        117677
# ..                         ...         ...       ...      ...           ...
# 631                Krishnagiri     1879809   1187958   877779        561634
# 633                   Tiruppur     2479052   1760566  1266137        819783
# 638                   Nicobars       36842     25332    17125         12714
# 639  North  AND Middle Andaman      105597     78683    38579         30612
# 640              South Andaman      238142    190266    96831         77563
#
# ...

# %%
df.iloc[:10,5:10]      #thats mean need 10 raw and 5 to 10 collumn
# Out:
#     Female_Workers  Cultivator_Workers  Agricultural_Workers  \
# 1            38165               34680                 56759
# 2            52288               55299                 36630
# 3            21814               20869                  1645
# 4            12034                8266                  3763
# 5            43716               54264                 31583
# 6           106160              136527                 24016
# 7            38883               69533                 21566
# 8            54619               57495                 62246
# 9            47937               28232                 32882
# 10           74037               12228                 10408
#
#     Household_Workers  Hindus
# 1                7946   37128
# 2               29102   10110
# 3                1020   22882
# 4                1222   10341
# 5                3930   32604
# 6                4656  221880
# 7                3952  540063
# 8               15084   30621
# ...

# %%
df.loc[[3,4,5,6,23,6,77,88,99],['Hindus','Female_Workers']]  #which raw and column we needed thn we are useing df.loc keyword
# Out:
#      Hindus  Female_Workers
# 3     22882           21814
# 4     10341           12034
# 5     32604           43716
# 6    221880          106160
# 23   479782          135244
# 6    221880          106160
# 77  1276669          155145
# 88  1588407          102296
# 99  1437144          316352

# %%
df.dtypes
# Out:
# District_name           object
# Population               int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
df.select_dtypes(include='int64')
# Out:
#      Population  Literate  Workers  Male_Workers  Female_Workers  \
# 1        870354    439654   229064        190899           38165
# 2        753745    335649   214866        162578           52288
# 3        133487     93770    75079         53265           21814
# 4        140802     86236    51873         39839           12034
# 5        476835    261724   161393        117677           43716
# ..          ...       ...      ...           ...             ...
# 636       41816     36470    11802          9093            2709
# 637      200222    154916    68301         53139           15162
# 638       36842     25332    17125         12714            4411
# 639      105597     78683    38579         30612            7967
# 640      238142    190266    96831         77563           19268
#
#      Cultivator_Workers  Agricultural_Workers  Household_Workers  Hindus  \
# 1                 34680                 56759               7946   37128
# ...

# %%
df.select_dtypes(exclude='int64')
# Out:
#                  District_name
# 1                      Kupwara
# 2                       Badgam
# 3                  Leh(Ladakh)
# 4                       Kargil
# 5                        Punch
# ..                         ...
# 636                       Mahe
# 637                   Karaikal
# 638                   Nicobars
# 639  North  AND Middle Andaman
# 640              South Andaman
#
# [640 rows x 1 columns]

# %%
import numpy as np

# %%
random_col = np.random.randint(100, size=len(df))

# %%
random_col
# Out:
# array([28, 95, 61, 21, 83, 40,  2, 93, 80, 76, 51, 99, 36, 83, 26,  4, 49,
#        42, 50, 42, 73, 12, 32,  9, 63, 96, 13, 83, 49,  3, 32,  5, 76, 63,
#        16, 60, 75,  3, 29, 33, 61, 62, 75,  8, 32, 39, 11, 12,  3, 38, 64,
#        78, 91, 11, 95, 69, 43, 75, 17, 48, 62, 68, 57, 26, 47, 29, 99, 42,
#        99, 58, 61, 15, 55, 50, 81, 14, 59, 82, 63, 60, 90, 12, 87, 46, 52,
#        32, 95, 69, 93,  3, 63, 87, 52, 53, 55, 40, 40,  5, 53, 72, 96, 57,
#        73, 49, 71, 82, 27, 55, 76, 91, 51, 77, 68, 78, 81, 71, 83, 59, 89,
#        83, 44, 72, 36, 97, 78, 88, 73, 20, 21, 38, 70, 17, 62, 29, 11, 22,
#        17, 93, 15, 73, 56, 70, 33, 51, 87, 85, 39, 43, 98, 13, 54, 69, 68,
#        31, 13, 37, 68, 50, 13, 82, 17, 79, 31, 48, 75, 68, 88, 10, 39, 86,
#        28, 92, 75, 41, 17, 99, 24,  0, 61, 84, 28, 28, 19, 63,  2, 19, 57,
#        39, 39, 73, 24, 63, 73, 35, 60, 25, 91, 70, 26, 35, 11, 84, 58, 95,
# ...

# %%
df.insert(3, 'random_col', random_col)

# %%
df.head()
# Out:
#   District_name  Population  Literate  random_col  Workers  Male_Workers  \
# 1       Kupwara      870354    439654          28   229064        190899
# 2        Badgam      753745    335649          95   214866        162578
# 3   Leh(Ladakh)      133487     93770          61    75079         53265
# 4        Kargil      140802     86236          21    51873         39839
# 5         Punch      476835    261724          83   161393        117677
#
#    Female_Workers  Cultivator_Workers  Agricultural_Workers  \
# 1           38165               34680                 56759
# 2           52288               55299                 36630
# 3           21814               20869                  1645
# 4           12034                8266                  3763
# 5           43716               54264                 31583
#
#    Household_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# 1               7946  ...        1700   5600         66     39
# ...

# %%
df.sample(n=600)
# Out:
#         District_name  Population  Literate  random_col  Workers  \
# 594          Thrissur     3121200   2678548          99  1095727
# 296  West Khasi Hills      383461    230678          98   163345
# 241   North  District       43709     30450          72    23359
# 342           Kolkata     4496694   3588137          51  1795740
# 626    Ramanathapuram     1353445    978946          35   602977
# ..                ...         ...       ...         ...      ...
# 143           Aligarh     3673889   2092567          33  1174361
# 565           Bellary     2452595   1421621          10  1116880
# 313          Golaghat     1066888    721764          56   479928
# 81            Bhiwani     1634445   1069871          90   623006
# 182         Balrampur     2148665    868357          28   760253
#
#      Male_Workers  Female_Workers  Cultivator_Workers  Agricultural_Workers  \
# 594        789511          306216               41786                 73941
# ...

# %%
df.sample(frac=0.25)
# Out:
#        District_name  Population  Literate  random_col  Workers  Male_Workers  \
# 195         Ghazipur     3620268   2197549          60  1204602        808700
# 53           Sangrur     1655169   1002077          91   568758        485129
# 73           Kaithal     1074304    646529          55   373899        292696
# 542       Srikakulam     2703114   1495381          62  1290288        766483
# 304         Morigaon      957423    539902           3   351148        257984
# ..               ...         ...       ...         ...      ...           ...
# 251       East Siang       99214     62576          70    40222         23591
# 136           Rampur     2335819   1043666          22   737261        609693
# 582  Chikkaballapura     1255104    783222          77   639778        384452
# 578   Chamarajanagar     1020791    565279          38   481693        324326
# 192              Mau     2205968   1363044          63   696747        475413
#
# ...

# %%
df['random_col'].where(df['random_col'] > 50)
# Out:
# 1       NaN
# 2      95.0
# 3      61.0
# 4       NaN
# 5      83.0
#        ...
# 636     NaN
# 637     NaN
# 638     NaN
# 639    62.0
# 640     NaN
# Name: random_col, Length: 640, dtype: float64

# %%
df['random_col'].where(df['random_col'] > 50, 0)
# Out:
# 1       0
# 2      95
# 3      61
# 4       0
# 5      83
#        ..
# 636     0
# 637     0
# 638     0
# 639    62
# 640     0
# Name: random_col, Length: 640, dtype: int32

# %%
df.nunique()
# Out:
# District_name           634
# Population              640
# Literate                640
# random_col              100
# Workers                 640
# Male_Workers            640
# Female_Workers          640
# Cultivator_Workers      639
# Agricultural_Workers    640
# Household_Workers       632
# Hindus                  640
# Muslims                 639
# Christians              622
# Sikhs                   565
# Buddhists               511
# Jains                   546
# Secondary_Education     640
# Higher_Education        640
# Graduate_Education      637
# Age_Group_0_29          640
# Age_Group_30_49         640
# Age_Group_50            639
# dtype: int64
